# %% [markdown]
# <a href="https://colab.research.google.com/github/MariamMakhlof/angora/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/BitcoinHeistData.csv')
df
# Out:
#                                   address    year    day  length    weight  \
# 0       111K8kZAEnJg245r2cM6y9zgJGHZtJPy6  2017.0   11.0    18.0  0.008333
# 1      1123pJv8jzeFQaCV4w644pzQJzVWay2zcA  2016.0  132.0    44.0  0.000244
# 2      112536im7hy6wtKbpH1qYDWtTyMRAcA2p7  2016.0  246.0     0.0  1.000000
# 3      1126eDRw2wqSkWosjTCre8cjjQW8sSeWH7  2016.0  322.0    72.0  0.003906
# 4      1129TSjKtx65E35GiUo4AYVeyo48twbrGX  2016.0  238.0   144.0  0.072848
# ...                                   ...     ...    ...     ...       ...
# 34944  1MBwkTssJkqRvXmAFcSEZ3xTD39A9rkyYA  2016.0  336.0   144.0  0.001114
# 34945  1MBwkTssJkqRvXmAFcSEZ3xTD39A9rkyYA  2016.0  340.0   144.0  0.045198
# 34946  1MBwkTssJkqRvXmAFcSEZ3xTD39A9rkyYA  2016.0  333.0   144.0  0.275371
# 34947  1MBwkTssJkqRvXmAFcSEZ3xTD39A9rkyYA  2016.0  344.0     4.0  0.250000
# 34948                1MbXszNH83GTKr92U5br     NaN    NaN     NaN       NaN
#
#         count  looped  neighbors       income            label
# ...
